# %% [markdown]
# ### POSTTEST 3
# <h4> Muhammad Faisal Setiawan </h4>
# <h4> 2009106060 </h4>

# %% [markdown]
# <h3> jadi kita import dulu library pandas, matplotlib, seaborn </3>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("CarRentalData.csv")

# %% [markdown]
# <h3> Melihat dataset yang kita gunakan </h3>

# %%
df
# Out:
#       fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0     ELECTRIC    5.00                13           12       Seattle
# 1     ELECTRIC    5.00                 2            1       Tijeras
# 2       HYBRID    4.92                28           24   Albuquerque
# 3     GASOLINE    5.00                21           20   Albuquerque
# 4     GASOLINE    5.00                 3            1   Albuquerque
# ...        ...     ...               ...          ...           ...
# 5846  GASOLINE    5.00                32           27      Honolulu
# 5847    HYBRID    5.00                17           16          Aiea
# 5848  GASOLINE    4.94                18           17        Kailua
# 5849  GASOLINE     NaN                 1            0       Waipahu
# 5850  GASOLINE    5.00                16           14        Kailua
#
#      location.country  location.latitude  location.longitude location.state  \
# ...

# %% [markdown]
# <h3> Menggunakan visualisasi bar <h/3>
# <h3> lalu disini saya ada dua sumbu x dan y, yang dimana saya mengambil data atribut tipe kendaraan dan tahun kendaraan </h3>

# %%
x = df['vehicle.year']
y = df['vehicle.type']
warna = '#696969'

# %%
plt.bar(x, y, align="edge", width=0.6, color=warna)
plt.title("Kendaraan rental")
plt.xlabel("Banyak Tahun kendaraan")
plt.ylabel("Banyak Tipe Kendaraan")
plt.show()

# %% [markdown]
# <h3> Lalu untuk visualisasi yang kedua saya menggunakan grafik pie </h3>
# <h3> disini bisa dilihat untuk banyaknya tiap jenis tipe kendaraan rental </h3>

# %%
df['vehicle.type'].value_counts()
# Out:
# car        3659
# suv        1714
# minivan     232
# truck       191
# van          55
# Name: vehicle.type, dtype: int64

# %%
labels = df['vehicle.type'].value_counts().rename_axis('vehicle.type').reset_index(name='Jumlah')
labels
# Out:
#   vehicle.type  Jumlah
# 0          car    3659
# 1          suv    1714
# 2      minivan     232
# 3        truck     191
# 4          van      55

# %%
plt.figure(figsize=(7,7), dpi=200)
plt.pie(df['vehicle.type'].value_counts(), labels=labels['vehicle.type'], autopct='%.1f%%', startangle=65)
plt.show()

# %% [markdown]
# <h4> Grafik scatterplot atau yang memiliki nama lain grafik pencar merupakan diagram grafis
# yang dibangun dari dua sumbu X dan Y (variabel X dan variabel Y) </h4>

# %%
df = pd.read_csv('CarRentalData.csv')
df.head()
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0  ELECTRIC    5.00                13           12       Seattle
# 1  ELECTRIC    5.00                 2            1       Tijeras
# 2    HYBRID    4.92                28           24   Albuquerque
# 3  GASOLINE    5.00                21           20   Albuquerque
# 4  GASOLINE    5.00                 3            1   Albuquerque
#
#   location.country  location.latitude  location.longitude location.state  \
# 0               US          47.449107         -122.308841             WA
# 1               US          35.111060         -106.276551             NM
# 2               US          35.127163         -106.566681             NM
# 3               US          35.149726         -106.711425             NM
# 4               US          35.208659         -106.601008             NM
#
#    owner.id  rate.daily vehicle.make vehicle.model vehicle.type  vehicle.year
# ...

# %%
sns.scatterplot(data = df, x='location.latitude', y = 'fuelType')
plt.title("Berikut data bahan bakar kendaraan rental dengan lokasi lintang ")
plt.show()

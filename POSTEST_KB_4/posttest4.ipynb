# %% [markdown]
# <h5> Muhammad Faisal Setiawan </h5>
# <h5> 2009106060 </h5>
#
# <h2> Masukan library yang di perlukan pada posstest kali ini, berikut : </h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# <h3> Melihat data csv yang akan digunakan </h3>

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# ...

# %% [markdown]
# <h3> melihat tipe data serta isi record </h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manufacturer_name  38531 non-null  object
#  1   model_name         38531 non-null  object
#  2   transmission       38531 non-null  object
#  3   color              38531 non-null  object
#  4   odometer_value     38531 non-null  int64
#  5   year_produced      38531 non-null  int64
#  6   engine_fuel        38531 non-null  object
#  7   engine_has_gas     38531 non-null  bool
#  8   engine_type        38531 non-null  object
#  9   engine_capacity    38521 non-null  float64
#  10  body_type          38531 non-null  object
#  11  has_warranty       38531 non-null  bool
#  12  state              38531 non-null  object
#  13  drivetrain         38531 non-null  object
#  14  price_usd          38531 non-null  float64
#  15  is_exchangeable    38531 non-null  bool
# ...

# %%
df.isna().sum()
# Out:
# manufacturer_name     0
# model_name            0
# transmission          0
# color                 0
# odometer_value        0
# year_produced         0
# engine_fuel           0
# engine_has_gas        0
# engine_type           0
# engine_capacity      10
# body_type             0
# has_warranty          0
# state                 0
# drivetrain            0
# price_usd             0
# is_exchangeable       0
# location_region       0
# number_of_photos      0
# up_counter            0
# feature_0             0
# feature_1             0
# feature_2             0
# feature_3             0
# feature_4             0
# feature_5             0
# feature_6             0
# feature_7             0
# feature_8             0
# feature_9             0
# duration_listed       0
# dtype: int64

# %%
df2 = pd.read_csv('CarRentalData.csv')
df2.head()
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0  ELECTRIC    5.00                13           12       Seattle
# 1  ELECTRIC    5.00                 2            1       Tijeras
# 2    HYBRID    4.92                28           24   Albuquerque
# 3  GASOLINE    5.00                21           20   Albuquerque
# 4  GASOLINE    5.00                 3            1   Albuquerque
#
#   location.country  location.latitude  location.longitude location.state  \
# 0               US          47.449107         -122.308841             WA
# 1               US          35.111060         -106.276551             NM
# 2               US          35.127163         -106.566681             NM
# 3               US          35.149726         -106.711425             NM
# 4               US          35.208659         -106.601008             NM
#
#    owner.id  rate.daily vehicle.make vehicle.model vehicle.type  vehicle.year
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5851 entries, 0 to 5850
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fuelType            5776 non-null   object
#  1   rating              5350 non-null   float64
#  2   renterTripsTaken    5851 non-null   int64
#  3   reviewCount         5851 non-null   int64
#  4   location.city       5851 non-null   object
#  5   location.country    5851 non-null   object
#  6   location.latitude   5851 non-null   float64
#  7   location.longitude  5851 non-null   float64
#  8   location.state      5851 non-null   object
#  9   owner.id            5851 non-null   int64
#  10  rate.daily          5851 non-null   int64
#  11  vehicle.make        5851 non-null   object
#  12  vehicle.model       5851 non-null   object
#  13  vehicle.type        5851 non-null   object
#  14  vehicle.year        5851 non-null   int64
# ...

# %%
df2.isna().sum()
# Out:
# fuelType               75
# rating                501
# renterTripsTaken        0
# reviewCount             0
# location.city           0
# location.country        0
# location.latitude       0
# location.longitude      0
# location.state          0
# owner.id                0
# rate.daily              0
# vehicle.make            0
# vehicle.model           0
# vehicle.type            0
# vehicle.year            0
# dtype: int64

# %%
print(f'panjang dataset {len(df)} baris')
# Out:
# panjang dataset 38531 baris

# %% [markdown]
# <h3> data split </h3>

# %%
data = df[['engine_capacity']]
label = df['model_name']
data_train, data_test, label_train, label_test = train_test_split(data, label, test_size=.3)

# %%
print(f'data training {len(data_train)}',
     f'label training {len(label_train)}',
     f'data testing {len(data_test)}',
     f'label testing {len(label_test)}',
     sep='\n')
# Out:
# data training 26971
# label training 26971
# data testing 11560
# label testing 11560

# %% [markdown]
# <h3> data transformasi </h3>

# %%
dataset_normalisasi = df2.copy()
dataset_standarirasi = df2.copy()

# %%
scaler = MinMaxScaler()
normalize_dataset = scaler.fit_transform(dataset_normalisasi[['rate.daily', 'owner.id', 'renterTripsTaken']])
normalize_dataset = pd.DataFrame(normalize_dataset)
normalize_dataset.rename(columns={ 0 :'rate.daily', 1 : 'owner.id', 2 : 'renterTripsTaken'}, inplace=True)
normalize_dataset.head(5)
# Out:
#    rate.daily  owner.id  renterTripsTaken
# 0    0.077703  0.812520          0.032911
# 1    0.114865  0.988002          0.005063
# 2    0.010135  0.644964          0.070886
# 3    0.037162  0.592213          0.053165
# 4    0.018243  0.224504          0.007595

# %%
stdsc = StandardScaler()
Scaled_data = stdsc.fit_transform(df2[['rate.daily', 'owner.id', 'renterTripsTaken']])

# %%
print("Nilai Sebelum Standarisasi : ")
print("Standar Deviasi : ", np.std(df))
# Out:
# Nilai Sebelum Standarisasi :
# Standar Deviasi :  odometer_value      136070.610766
# year_produced            8.065626
# engine_has_gas           0.183676
# engine_capacity          0.671169
# has_warranty             0.107318
# price_usd             6428.068602
# is_exchangeable          0.477779
# number_of_photos         6.093138
# up_counter              43.286371
# feature_0                0.419894
# feature_1                0.488373
# feature_2                0.416803
# feature_3                0.446918
# feature_4                0.427973
# feature_5                0.478838
# feature_6                0.376491
# feature_7                0.440658
# feature_8                0.492778
# feature_9                0.493655
# duration_listed        112.825105
# dtype: float64
# ...

# %%
print("Nilai Setelah Standarisasi : ")
print("Standar Deviasi : ", np.std(Scaled_data))
# Out:
# Nilai Setelah Standarisasi :
# Standar Deviasi :  1.0

# %% [markdown]
# <h3> Data Cleaning </h3>

# %%
dataset_mn = df.copy()
dataset_md = df2.copy()
dataset_ms = df.copy()

# %%
imputer_mean = SimpleImputer(strategy='mean')
imputer_median = SimpleImputer(strategy='median')
imputer_modus = SimpleImputer(strategy='most_frequent')

# %% [markdown]
# <h3> MODUS </h3>

# %%
dataset_mn['engine_capacity'] = imputer_mean.fit_transform(dataset_mn[['engine_capacity']])

dataset_mn.isna().sum()
# Out:
# manufacturer_name    0
# model_name           0
# transmission         0
# color                0
# odometer_value       0
# year_produced        0
# engine_fuel          0
# engine_has_gas       0
# engine_type          0
# engine_capacity      0
# body_type            0
# has_warranty         0
# state                0
# drivetrain           0
# price_usd            0
# is_exchangeable      0
# location_region      0
# number_of_photos     0
# up_counter           0
# feature_0            0
# feature_1            0
# feature_2            0
# feature_3            0
# feature_4            0
# feature_5            0
# feature_6            0
# feature_7            0
# feature_8            0
# feature_9            0
# duration_listed      0
# dtype: int64

# %% [markdown]
# <h3> median </h3>

# %%
dataset_md['rating'] = imputer_median.fit_transform(dataset_md[['rating']])

dataset_md.isna().sum()
# Out:
# fuelType              75
# rating                 0
# renterTripsTaken       0
# reviewCount            0
# location.city          0
# location.country       0
# location.latitude      0
# location.longitude     0
# location.state         0
# owner.id               0
# rate.daily             0
# vehicle.make           0
# vehicle.model          0
# vehicle.type           0
# vehicle.year           0
# dtype: int64

# %%
dataset_md.dropna(inplace=True)
dataset_md.isna().sum()
# Out:
# fuelType              0
# rating                0
# renterTripsTaken      0
# reviewCount           0
# location.city         0
# location.country      0
# location.latitude     0
# location.longitude    0
# location.state        0
# owner.id              0
# rate.daily            0
# vehicle.make          0
# vehicle.model         0
# vehicle.type          0
# vehicle.year          0
# dtype: int64

# %%
len(dataset_mn)
# Out:
# 38531

# %% [markdown]
# <h3> data duplikat </h3>

# %%
dataset_duplicate = df.copy()
dataset_duplicate.duplicated().sum()
# Out:
# 40

# %%
dataset_duplicate.drop_duplicates(inplace=True)
dataset_duplicate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h3> encoding </h3>

# %%
dataset_ordinal = df.copy()
dataset_one_hot = df.copy()

# %%
df['engine_has_gas'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# <h3> ordinal </h3>

# %%
encoder_ordinal =OrdinalEncoder()
dataset_ordinal['engine_has_gas'] = encoder_ordinal.fit_transform(dataset_ordinal[['engine_has_gas']]).astype('int64')
dataset_ordinal
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
dataset_ordinal['engine_has_gas'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# <h3> one hot </h3>

# %%
temp_dataset = pd.get_dummies(dataset_one_hot[['engine_has_gas']])
temp_dataset = pd.DataFrame(temp_dataset)
dataset_one_hot.drop('engine_has_gas', axis=1, inplace=True)
dataset_one_hot = dataset_one_hot.join(temp_dataset)
dataset_one_hot.head(5)
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel engine_type  engine_capacity  body_type  ...  \
# 0           2010    gasoline    gasoline              2.5  universal  ...
# 1           2002    gasoline    gasoline              3.0  universal  ...
# 2           2001    gasoline    gasoline              2.5        suv  ...
# 3           1999    gasoline    gasoline              3.0      sedan  ...
# 4           2001    gasoline    gasoline              2.5  universal  ...
#
#    feature_2 feature_3 feature_4  feature_5  feature_6 feature_7  feature_8  \
# ...

# %% [markdown]
# <h4> Mengimpor library pandas </h4>

# %%
import pandas as pd

# %%
df = pd.read_csv("CarRentalData.csv")

# %% [markdown]
# <h4> Melihat dataset yang ada </h4>

# %%
df
# Out:
#       fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0     ELECTRIC    5.00                13           12       Seattle
# 1     ELECTRIC    5.00                 2            1       Tijeras
# 2       HYBRID    4.92                28           24   Albuquerque
# 3     GASOLINE    5.00                21           20   Albuquerque
# 4     GASOLINE    5.00                 3            1   Albuquerque
# ...        ...     ...               ...          ...           ...
# 5846  GASOLINE    5.00                32           27      Honolulu
# 5847    HYBRID    5.00                17           16          Aiea
# 5848  GASOLINE    4.94                18           17        Kailua
# 5849  GASOLINE     NaN                 1            0       Waipahu
# 5850  GASOLINE    5.00                16           14        Kailua
#
#      location.country  location.latitude  location.longitude location.state  \
# ...

# %% [markdown]
# <h3> ini adalah informasi, yaitu ada record, float, objek, ankga, dan null </h3>

# %%
df.dtypes
# Out:
# fuelType               object
# rating                float64
# renterTripsTaken        int64
# reviewCount             int64
# location.city          object
# location.country       object
# location.latitude     float64
# location.longitude    float64
# location.state         object
# owner.id                int64
# rate.daily              int64
# vehicle.make           object
# vehicle.model          object
# vehicle.type           object
# vehicle.year            int64
# dtype: object

# %% [markdown]
# <h4> Masukkan informasi di atas dalam dictionary dengan key sesuai nama informasinya </h4>

# %%
JumlahRecord = len(df)
namaAttribute = df.columns
jumlahObjek = len(df.select_dtypes(include=['object']).columns)
jumlahAngka = len(df.select_dtypes(include=['int64', 'float64']).columns)
jumlahNULL = len(df.columns[df.isna().sum() > 0])

dictionary_no1 = {
    "Jumlah record"  : JumlahRecord,
    "Nama Attribute" : namaAttribute,
    "Jumlah Objek"   : jumlahObjek,
    "Jumlah Angka"   : jumlahAngka,
    "Jumlah NULL"    : jumlahNULL,
}

pd.Series(dictionary_no1)
# Out:
# Jumlah record                                                  5851
# Nama Attribute    Index(['fuelType', 'rating', 'renterTripsTaken...
# Jumlah Objek                                                      7
# Jumlah Angka                                                      8
# Jumlah NULL                                                       2
# dtype: object

# %% [markdown]
# <h4> Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka </h4>

# %% [markdown]
# <h4> Tampilkan Nilai rata-rata dengan fungsi mean </h4>

# %%
df.select_dtypes(include=['int64' , 'float64']).mean()
# Out:
# rating                4.920325e+00
# renterTripsTaken      3.347735e+01
# reviewCount           2.845479e+01
# location.latitude     3.558289e+01
# location.longitude   -9.963277e+01
# owner.id              6.034830e+06
# rate.daily            9.369151e+01
# vehicle.year          2.015340e+03
# dtype: float64

# %% [markdown]
# <h4> Tampilkan Nilai Standar deviasi </h4>

# %%
df.select_dtypes(include=['int64', 'float64']).std()
# Out:
# rating                1.824253e-01
# renterTripsTaken      4.189895e+01
# reviewCount           3.513611e+01
# location.latitude     6.431408e+00
# location.longitude    2.039148e+01
# owner.id              4.646022e+06
# rate.daily            9.608092e+01
# vehicle.year          4.050813e+00
# dtype: float64

# %% [markdown]
# <h4> Tampilkan Nilai Min</h4>

# %%
df.select_dtypes(include=['int64', 'float64']).min()
# Out:
# rating                   1.000000
# renterTripsTaken         0.000000
# reviewCount              0.000000
# location.latitude       21.272565
# location.longitude    -158.165693
# owner.id              5105.000000
# rate.daily              20.000000
# vehicle.year          1955.000000
# dtype: float64

# %% [markdown]
# <h4> Tampilkan Nilai Max </h4>

# %%
df.select_dtypes(include=['int64', 'float64']).max()
# Out:
# rating                5.000000e+00
# renterTripsTaken      3.950000e+02
# reviewCount           3.210000e+02
# location.latitude     6.489361e+01
# location.longitude   -6.882364e+01
# owner.id              1.581088e+07
# rate.daily            1.500000e+03
# vehicle.year          2.020000e+03
# dtype: float64

# %% [markdown]
# <h4> Tampilkan Nilai Q1, Q2, dan Q3 dengan fungsi quantile </h4>

# %%
df.select_dtypes(include=['int64', 'float64']).quantile([0.25,0.5,0.75])
# Out:
#       rating  renterTripsTaken  reviewCount  location.latitude  \
# 0.25     4.9               5.0          4.0          30.453623
# 0.50     5.0              18.0         16.0          35.554502
# 0.75     5.0              46.0         39.0          39.996864
#
#       location.longitude   owner.id  rate.daily  vehicle.year
# 0.25         -117.158285  1917451.0        45.0        2014.0
# 0.50          -95.673319  4968749.0        69.0        2016.0
# 0.75          -81.538631  9657496.5       110.0        2018.0

# %% [markdown]
# <h4> Menampilakn semua sekaligus diatas dengan fungsi .describe() </h4>

# %%
df.describe()
# Out:
#             rating  renterTripsTaken  reviewCount  location.latitude  \
# count  5350.000000       5851.000000  5851.000000        5851.000000
# mean      4.920325         33.477354    28.454794          35.582889
# std       0.182425         41.898954    35.136113           6.431408
# min       1.000000          0.000000     0.000000          21.272565
# 25%       4.900000          5.000000     4.000000          30.453623
# 50%       5.000000         18.000000    16.000000          35.554502
# 75%       5.000000         46.000000    39.000000          39.996864
# max       5.000000        395.000000   321.000000          64.893610
#
#        location.longitude      owner.id   rate.daily  vehicle.year
# count         5851.000000  5.851000e+03  5851.000000   5851.000000
# mean           -99.632773  6.034830e+06    93.691506   2015.340113
# std             20.391476  4.646022e+06    96.080920      4.050813
# min           -158.165693  5.105000e+03    20.000000   1955.000000
# ...

# %% [markdown]
# <h4>Tampilkan nilai korelasi attribute bertipe angka. </h4>

# %%
df.select_dtypes(include=['int64', 'float64']).corr()
# Out:
#                       rating  renterTripsTaken  reviewCount  \
# rating              1.000000         -0.054883    -0.040144
# renterTripsTaken   -0.054883          1.000000     0.994177
# reviewCount        -0.040144          0.994177     1.000000
# location.latitude  -0.002643          0.010998     0.007881
# location.longitude -0.015799         -0.053036    -0.047017
# owner.id            0.051674         -0.331197    -0.325160
# rate.daily          0.086745         -0.104027    -0.100856
# vehicle.year        0.108765         -0.123407    -0.111388
#
#                     location.latitude  location.longitude  owner.id  \
# rating                      -0.002643           -0.015799  0.051674
# renterTripsTaken             0.010998           -0.053036 -0.331197
# reviewCount                  0.007881           -0.047017 -0.325160
# location.latitude            1.000000           -0.012547  0.006748
# location.longitude          -0.012547            1.000000  0.020020
# ...

# %% [markdown]
# <h4> Rubah nilai salah satu attribute bertipe angka menjadi dari desimal menjadi bilangan bulat </h4>

# %%
df["rating"] = df["rating"].astype('int64', errors='ignore')
df["rating"].dtypes
# Out:
# dtype('float64')

# %%
df["rating"] = df["rating"].astype('float64', errors='ignore')

# %%
df = df.fillna(0)
df.rating.astype('int64')
# Out:
# 0       5
# 1       5
# 2       4
# 3       5
# 4       5
#        ..
# 5846    5
# 5847    5
# 5848    4
# 5849    0
# 5850    5
# Name: rating, Length: 5851, dtype: int64

# %% [markdown]
# <h4> Tampilkan 10 record pertama dari attribute bertipe angka. </h4>

# %%
df.select_dtypes(include=['int64', 'float64']).head(10)
# Out:
#    rating  renterTripsTaken  reviewCount  location.latitude  \
# 0    5.00                13           12          47.449107
# 1    5.00                 2            1          35.111060
# 2    4.92                28           24          35.127163
# 3    5.00                21           20          35.149726
# 4    5.00                 3            1          35.208659
# 5    5.00                13           12          35.068834
# 6    4.42                13           12          35.045552
# 7    4.90                12           10          35.186542
# 8    5.00                 1            1          35.061213
# 9    4.76                22           17          35.115363
#
#    location.longitude  owner.id  rate.daily  vehicle.year
# 0         -122.308841  12847615         135          2019
# 1         -106.276551  15621242         190          2018
# 2         -106.566681  10199256          35          2012
# 3         -106.711425   9365496          75          2018
# ...

# %% [markdown]
# <h4> Simpan dataset dengan attribute bertipe angka ke dalam file CSV </h4>

# %%
df.select_dtypes(include=['int64', 'float64']).to_csv("Atribut_Bertipe Angka_CarRentalData.csv", index=False)
